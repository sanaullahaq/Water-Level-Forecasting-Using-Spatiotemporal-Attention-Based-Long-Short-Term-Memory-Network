# %%
# !nvidia-smi
# Out:
# Sat Sep  4 15:14:39 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.63.01    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   61C    P8    32W / 149W |      0MiB / 11441MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# # Imports

# %%
import pandas as pd
import torch
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms
import torch.nn as nn
import torch.nn.functional as F
from tqdm.auto import tqdm
import numpy as np
from torch.autograd import Variable

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Setting the parameters

# %%
EXCEL_PATH = '/content/drive/MyDrive/CSE419/Data Mining.xlsx'
LEARNING_RATE = 0.01
RANDOM_SEED = 42

# %% [markdown]
# # Dataset Analysis

# %%
df = pd.read_excel(EXCEL_PATH)
df
# Out:
#            DATE  SW273  SW267  SW269
# 0    1979-06-01   2.60   5.52   5.42
# 1    1979-06-02   2.43   5.30   5.24
# 2    1979-06-03   2.40   5.07   5.09
# 3    1979-06-04   2.29   4.87   4.94
# 4    1979-06-05   2.20   4.69   4.79
# ...         ...    ...    ...    ...
# 5010 2009-10-27   3.50   6.13   5.59
# 5011 2009-10-28   3.34   5.97   5.50
# 5012 2009-10-29   3.20   5.82   5.42
# 5013 2009-10-30   3.12   5.70   5.36
# 5014 2009-10-31   3.06   5.61   5.30
#
# [5015 rows x 4 columns]

# %%
# df[['SW267', 'SW269']].iloc[0]

# %%
df.describe()
# Out:
#              SW273        SW267        SW269
# count  5015.000000  5015.000000  5015.000000
# mean      4.971986     8.797886     7.088640
# std       1.248850     2.063672     1.233145
# min       1.670000     3.140000     3.180000
# 25%       4.050000     7.730000     6.460000
# 50%       5.300000     9.510000     7.430000
# 75%       5.900000    10.340000     7.970000
# max       7.780000    12.440000     9.750000

# %%
df.SW273.isnull().sum(), df.SW267.isnull().sum(), df.SW269.isnull().sum()
# Out:
# (0, 0, 0)

# %% [markdown]
# # GPU or CPU

# %%
DEVICE = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
DEVICE
# Out:
# device(type='cuda')

# %% [markdown]
# # Custom Dataset Class

# %%
class FloodDataset(Dataset):
  """Custom Dataset class to work with FloodDataset"""
  def __init__(self, excel_path, train, items=None):
    df = pd.read_excel(excel_path)
    
    if items and train==True:
      df = df[:items]

    elif items and train==False:
      df = df[-items:]

    df['index'] = range(0, len(df))
    df = df.set_index('index')
    
    self.excel_path = excel_path
    self.features = df[['SW273','SW269']]
    self.targets = df[['SW267']]

  def __getitem__(self, index):
    return torch.tensor(self.features.iloc[index], dtype=torch.float32), torch.tensor(self.targets.iloc[index], dtype=torch.float32)

  def __len__(self):
    return len(self.features)

# %% [markdown]
# # Dataset and Dataloader

# %%
train_dataset = FloodDataset(excel_path=EXCEL_PATH,
                             train=True,
                             items = 4011)
test_dataset = FloodDataset(excel_path=EXCEL_PATH,
                             train=False,
                             items = 1003)
print(f'Length Train Dataset: {len(train_dataset)} \nLength of Test Dataset: {len(test_dataset)}')

train_loader = DataLoader(dataset=train_dataset,
                          batch_size = 1000,
                          shuffle=False,
                          num_workers = 0)
test_loader = DataLoader(dataset=test_dataset,
                         batch_size = 1003,
                         shuffle=False,
                         num_workers=0)

print(f'Length Train Loader: {len(train_loader)} \nLength of Test Loader: {len(test_loader)}')
# Out:
# Length Train Dataset: 4011
# Length of Test Dataset: 1003
# Length Train Loader: 5
# Length of Test Loader: 1

# %%
# train_dataset.input, train_dataset.output
# test_dataset.input, test_dataset.output

# %%
# sample = next(iter(train_loader))
# print(len(sample))
# inp, out = sample
# print(inp.shape, out.shape)
# type(inp) ,type(out)

# %% [markdown]
# # Building the ANN Model

# %%
class ANN(nn.Module):
  def __init__(self, input_size, hidden_size,hidden_size_2, num_classes):
    super(ANN, self).__init__()
    self.fc1 = nn.Linear(in_features=input_size, out_features=hidden_size)
    self.relu1 = nn.ReLU()
    self.fc2 = nn.Linear(in_features=hidden_size, out_features=hidden_size_2)
    self.relu2 = nn.ReLU()
    self.output_layer = nn.Linear(in_features=hidden_size_2, out_features=num_classes)

  def forward(self, x):
#     x = x.reshape(x.size(0), 1)
    x = self.fc1(x)
    x = self.relu1(x)
    x = self.fc2(x)
    x = self.relu2(x)
    x = self.output_layer(x)
    return x

# %% [markdown]
# # Initializing an ANN object with Optimizer

# %%
torch.manual_seed(RANDOM_SEED)
torch.cuda.manual_seed(RANDOM_SEED)

model = ANN(2,30,15,1)
model = model.to(DEVICE)

optimizer = torch.optim.SGD(model.parameters(), momentum = 0.5, lr = LEARNING_RATE)
optimizer = torch.optim.Adam(model.parameters(), lr = LEARNING_RATE)

# %%
print(model)
# Out:
# ANN(
#   (fc1): Linear(in_features=2, out_features=30, bias=True)
#   (relu1): ReLU()
#   (fc2): Linear(in_features=30, out_features=15, bias=True)
#   (relu2): ReLU()
#   (output_layer): Linear(in_features=15, out_features=1, bias=True)
# )

# %% [markdown]
# # Evaluation and Loss Function

# %%
def Loss(preds, targets, train):
    error = preds-targets
    abs_error = torch.abs(error)
    
    mse = torch.sum(error**2)
    rmse = torch.sqrt(mse/len(preds))
    
    if train==True:
        return mse, rmse
    else:
        mae = torch.sum(abs_error)
        mape = torch.sum(torch.abs((targets-preds)/targets))

        targets_mean = torch.mean(targets)
        preds_mean = torch.mean(preds)
        r_square_numerator = torch.sum((targets-targets_mean)*(preds-preds_mean))**2
        r_square_denominator = torch.sum((targets-targets_mean)**2)*torch.sum((preds-preds_mean)**2)
        r_square = r_square_numerator / r_square_denominator

        esd = torch.sum((abs_error - torch.mean(abs_error))**2)
        return mse, rmse, mae, mape, r_square, esd

# %%
def calculate_scores(model, data_loader, DEVICE):
  criterion = Loss 
  train_examples = 0
  total_mae = total_mse = total_mape = total_r_square = total_esd = 0.0

  for batch, (features, targets) in enumerate(data_loader):
    features, targets = features.to(DEVICE), targets.to(DEVICE)
    preds = model(features)
    
    mse, rmse, mae, mape, r_square, esd = criterion(preds, targets, train=False)
    total_mae += mae
    total_mse += mse
    total_mape += mape
    train_examples +=len(features)
    total_r_square += r_square
    total_esd += esd

  total_RMSE_loss = format(torch.sqrt((total_mse)/train_examples), '.5f')
  total_mse_loss = format(total_mse/train_examples, '.5f')
  total_mae_loss = format(total_mae/train_examples, '.5f')
  total_mape_loss = format(total_mape/train_examples, '.5f')
  total_r_square = format(total_r_square, '.5f')
  total_esd = format(torch.sqrt(esd/train_examples), '.5f')
  

  # print(f'total_RMSE_loss: {total_RMSE_loss}\ntotal_mse_loss: {total_mse_loss}\ntotal_mae_loss: {total_mae_loss}\ntotal_mape_loss: {total_mape_loss}\ntotal_r_square:{total_r_square}\ntotal_esd: {total_esd}')
  return total_RMSE_loss, total_mse_loss, total_mae_loss, total_mape_loss, total_r_square, total_esd

# %% [markdown]
# # Train the ANN

# %%
result_dict = {}
criterion = Loss

for epoch in range(1,201):    
  train_examples = 0
  train_loss = 0

  for batch ,(features, targets) in enumerate(train_loader):
    features, targets = features.to(DEVICE), targets.to(DEVICE)
    preds = model(features)
    # print(type(preds), preds.shape)
    mse_loss, rmse_loss = criterion(preds, targets, train=True)
    optimizer.zero_grad()
    rmse_loss.backward()
    optimizer.step()
    
    train_examples += len(features)
    train_loss += mse_loss
  
  train_loss = torch.sqrt(train_loss/train_examples)
  print(f'Epoch = {epoch} RMSE Training Loss = {format(train_loss, ".5f")}')
  
  if epoch%10==0:
    print(f'\n\n\nTraining Eneded for {epoch} epochs')
    model.eval()
    with torch.set_grad_enabled(False):
      total_RMSE_loss, total_mse_loss, total_mae_loss, total_mape_loss, total_r_square, total_esd = calculate_scores(model, test_loader, DEVICE)
      print(f'MAPE: {total_mape_loss}')
      result_dict[str(epoch)+'E'] = total_mape_loss
# Out:
# Epoch = 1 RMSE Training Loss = 7.97799
# Epoch = 2 RMSE Training Loss = 5.20997
# Epoch = 3 RMSE Training Loss = 1.51196
# Epoch = 4 RMSE Training Loss = 2.19524
# Epoch = 5 RMSE Training Loss = 1.24708
# Epoch = 6 RMSE Training Loss = 1.38783
# Epoch = 7 RMSE Training Loss = 1.05295
# Epoch = 8 RMSE Training Loss = 0.96204
# Epoch = 9 RMSE Training Loss = 0.88485
# Epoch = 10 RMSE Training Loss = 0.88072
#
#
#
# Training Eneded for 10 epochs
# MAPE: 0.07653
# Epoch = 11 RMSE Training Loss = 0.86508
# Epoch = 12 RMSE Training Loss = 0.77851
# Epoch = 13 RMSE Training Loss = 0.81258
# Epoch = 14 RMSE Training Loss = 0.75997
# Epoch = 15 RMSE Training Loss = 0.77252
# Epoch = 16 RMSE Training Loss = 0.75701
# Epoch = 17 RMSE Training Loss = 0.75646
# Epoch = 18 RMSE Training Loss = 0.74876
# Epoch = 19 RMSE Training Loss = 0.74411
# Epoch = 20 RMSE Training Loss = 0.73630
#
#
#
# Training Eneded for 20 epochs
# MAPE: 0.07019
# Epoch = 21 RMSE Training Loss = 0.72781
# Epoch = 22 RMSE Training Loss = 0.72130
# Epoch = 23 RMSE Training Loss = 0.71134
# Epoch = 24 RMSE Training Loss = 0.70865
# Epoch = 25 RMSE Training Loss = 0.69644
# Epoch = 26 RMSE Training Loss = 0.69647
# Epoch = 27 RMSE Training Loss = 0.68189
# Epoch = 28 RMSE Training Loss = 0.68407
# Epoch = 29 RMSE Training Loss = 0.66854
# Epoch = 30 RMSE Training Loss = 0.67111
#
#
#
# Training Eneded for 30 epochs
# MAPE: 0.06279
# Epoch = 31 RMSE Training Loss = 0.65679
# Epoch = 32 RMSE Training Loss = 0.65779
# Epoch = 33 RMSE Training Loss = 0.64649
# Epoch = 34 RMSE Training Loss = 0.64471
# Epoch = 35 RMSE Training Loss = 0.63702
# Epoch = 36 RMSE Training Loss = 0.63253
# Epoch = 37 RMSE Training Loss = 0.62757
# Epoch = 38 RMSE Training Loss = 0.62159
# Epoch = 39 RMSE Training Loss = 0.61771
# Epoch = 40 RMSE Training Loss = 0.61189
#
#
#
# Training Eneded for 40 epochs
# MAPE: 0.05691
# Epoch = 41 RMSE Training Loss = 0.60789
# Epoch = 42 RMSE Training Loss = 0.60314
# Epoch = 43 RMSE Training Loss = 0.59877
# Epoch = 44 RMSE Training Loss = 0.59490
# Epoch = 45 RMSE Training Loss = 0.59069
# Epoch = 46 RMSE Training Loss = 0.58715
# Epoch = 47 RMSE Training Loss = 0.58351
# Epoch = 48 RMSE Training Loss = 0.58029
# Epoch = 49 RMSE Training Loss = 0.59212
# Epoch = 50 RMSE Training Loss = 0.55838
#
#
#
# Training Eneded for 50 epochs
# MAPE: 0.05302
# Epoch = 51 RMSE Training Loss = 0.58281
# Epoch = 52 RMSE Training Loss = 0.56693
# Epoch = 53 RMSE Training Loss = 0.56192
# Epoch = 54 RMSE Training Loss = 0.57005
# Epoch = 55 RMSE Training Loss = 0.55791
# Epoch = 56 RMSE Training Loss = 0.56047
# Epoch = 57 RMSE Training Loss = 0.55991
# Epoch = 58 RMSE Training Loss = 0.55419
# Epoch = 59 RMSE Training Loss = 0.55615
# Epoch = 60 RMSE Training Loss = 0.55367
#
#
#
# Training Eneded for 60 epochs
# MAPE: 0.04952
# Epoch = 61 RMSE Training Loss = 0.55140
# Epoch = 62 RMSE Training Loss = 0.55188
# Epoch = 63 RMSE Training Loss = 0.54981
# Epoch = 64 RMSE Training Loss = 0.54883
# Epoch = 65 RMSE Training Loss = 0.54857
# Epoch = 66 RMSE Training Loss = 0.54717
# Epoch = 67 RMSE Training Loss = 0.54662
# Epoch = 68 RMSE Training Loss = 0.54611
# Epoch = 69 RMSE Training Loss = 0.54519
# Epoch = 70 RMSE Training Loss = 0.54478
#
#
#
# Training Eneded for 70 epochs
# MAPE: 0.04787
# Epoch = 71 RMSE Training Loss = 0.54429
# Epoch = 72 RMSE Training Loss = 0.54369
# Epoch = 73 RMSE Training Loss = 0.54335
# Epoch = 74 RMSE Training Loss = 0.54292
# Epoch = 75 RMSE Training Loss = 0.54251
# Epoch = 76 RMSE Training Loss = 0.54221
# Epoch = 77 RMSE Training Loss = 0.54185
# Epoch = 78 RMSE Training Loss = 0.54153
# Epoch = 79 RMSE Training Loss = 0.54130
# Epoch = 80 RMSE Training Loss = 0.54102
#
#
#
# Training Eneded for 80 epochs
# MAPE: 0.04714
# Epoch = 81 RMSE Training Loss = 0.54078
# Epoch = 82 RMSE Training Loss = 0.54058
# Epoch = 83 RMSE Training Loss = 0.54037
# Epoch = 84 RMSE Training Loss = 0.54017
# Epoch = 85 RMSE Training Loss = 0.54000
# Epoch = 86 RMSE Training Loss = 0.53983
# Epoch = 87 RMSE Training Loss = 0.53967
# Epoch = 88 RMSE Training Loss = 0.53953
# Epoch = 89 RMSE Training Loss = 0.53938
# Epoch = 90 RMSE Training Loss = 0.53925
#
#
#
# Training Eneded for 90 epochs
# MAPE: 0.04684
# Epoch = 91 RMSE Training Loss = 0.53913
# Epoch = 92 RMSE Training Loss = 0.53900
# Epoch = 93 RMSE Training Loss = 0.53890
# Epoch = 94 RMSE Training Loss = 0.53879
# Epoch = 95 RMSE Training Loss = 0.53868
# Epoch = 96 RMSE Training Loss = 0.53857
# Epoch = 97 RMSE Training Loss = 0.53847
# Epoch = 98 RMSE Training Loss = 0.53838
# Epoch = 99 RMSE Training Loss = 0.53830
# Epoch = 100 RMSE Training Loss = 0.53821
#
#
#
# Training Eneded for 100 epochs
# MAPE: 0.04671
# Epoch = 101 RMSE Training Loss = 0.53814
# Epoch = 102 RMSE Training Loss = 0.53806
# Epoch = 103 RMSE Training Loss = 0.53799
# Epoch = 104 RMSE Training Loss = 0.53791
# Epoch = 105 RMSE Training Loss = 0.53784
# Epoch = 106 RMSE Training Loss = 0.53778
# Epoch = 107 RMSE Training Loss = 0.53771
# Epoch = 108 RMSE Training Loss = 0.53765
# Epoch = 109 RMSE Training Loss = 0.53759
# Epoch = 110 RMSE Training Loss = 0.53753
#
#
#
# Training Eneded for 110 epochs
# MAPE: 0.04664
# Epoch = 111 RMSE Training Loss = 0.53747
# Epoch = 112 RMSE Training Loss = 0.53740
# Epoch = 113 RMSE Training Loss = 0.53735
# Epoch = 114 RMSE Training Loss = 0.53730
# Epoch = 115 RMSE Training Loss = 0.53725
# Epoch = 116 RMSE Training Loss = 0.53720
# Epoch = 117 RMSE Training Loss = 0.53715
# Epoch = 118 RMSE Training Loss = 0.53710
# Epoch = 119 RMSE Training Loss = 0.53706
# Epoch = 120 RMSE Training Loss = 0.53701
#
#
#
# Training Eneded for 120 epochs
# MAPE: 0.04659
# Epoch = 121 RMSE Training Loss = 0.53696
# Epoch = 122 RMSE Training Loss = 0.53692
# Epoch = 123 RMSE Training Loss = 0.53687
# Epoch = 124 RMSE Training Loss = 0.53683
# Epoch = 125 RMSE Training Loss = 0.53680
# Epoch = 126 RMSE Training Loss = 0.53675
# Epoch = 127 RMSE Training Loss = 0.53671
# Epoch = 128 RMSE Training Loss = 0.53667
# Epoch = 129 RMSE Training Loss = 0.53664
# Epoch = 130 RMSE Training Loss = 0.53660
#
#
#
# Training Eneded for 130 epochs
# MAPE: 0.04657
# Epoch = 131 RMSE Training Loss = 0.53655
# Epoch = 132 RMSE Training Loss = 0.53652
# Epoch = 133 RMSE Training Loss = 0.53649
# Epoch = 134 RMSE Training Loss = 0.53645
# Epoch = 135 RMSE Training Loss = 0.53642
# Epoch = 136 RMSE Training Loss = 0.53638
# Epoch = 137 RMSE Training Loss = 0.53635
# Epoch = 138 RMSE Training Loss = 0.53633
# Epoch = 139 RMSE Training Loss = 0.53629
# Epoch = 140 RMSE Training Loss = 0.53626
#
#
#
# Training Eneded for 140 epochs
# MAPE: 0.04655
# Epoch = 141 RMSE Training Loss = 0.53621
# Epoch = 142 RMSE Training Loss = 0.53619
# Epoch = 143 RMSE Training Loss = 0.53616
# Epoch = 144 RMSE Training Loss = 0.53613
# Epoch = 145 RMSE Training Loss = 0.53612
# Epoch = 146 RMSE Training Loss = 0.53608
# Epoch = 147 RMSE Training Loss = 0.53604
# Epoch = 148 RMSE Training Loss = 0.53602
# Epoch = 149 RMSE Training Loss = 0.53601
# Epoch = 150 RMSE Training Loss = 0.53595
#
#
#
# Training Eneded for 150 epochs
# MAPE: 0.04654
# Epoch = 151 RMSE Training Loss = 0.53596
# Epoch = 152 RMSE Training Loss = 0.53591
# Epoch = 153 RMSE Training Loss = 0.53590
# Epoch = 154 RMSE Training Loss = 0.53587
# Epoch = 155 RMSE Training Loss = 0.53584
# Epoch = 156 RMSE Training Loss = 0.53584
# Epoch = 157 RMSE Training Loss = 0.53578
# Epoch = 158 RMSE Training Loss = 0.53576
# Epoch = 159 RMSE Training Loss = 0.53577
# Epoch = 160 RMSE Training Loss = 0.53571
#
#
#
# Training Eneded for 160 epochs
# MAPE: 0.04653
# Epoch = 161 RMSE Training Loss = 0.53569
# Epoch = 162 RMSE Training Loss = 0.53569
# Epoch = 163 RMSE Training Loss = 0.53566
# Epoch = 164 RMSE Training Loss = 0.53562
# Epoch = 165 RMSE Training Loss = 0.53561
# Epoch = 166 RMSE Training Loss = 0.53561
# Epoch = 167 RMSE Training Loss = 0.53556
# Epoch = 168 RMSE Training Loss = 0.53554
# Epoch = 169 RMSE Training Loss = 0.53554
# Epoch = 170 RMSE Training Loss = 0.53550
#
#
#
# Training Eneded for 170 epochs
# MAPE: 0.04652
# Epoch = 171 RMSE Training Loss = 0.53548
# Epoch = 172 RMSE Training Loss = 0.53547
# Epoch = 173 RMSE Training Loss = 0.53545
# Epoch = 174 RMSE Training Loss = 0.53543
# Epoch = 175 RMSE Training Loss = 0.53540
# Epoch = 176 RMSE Training Loss = 0.53538
# Epoch = 177 RMSE Training Loss = 0.53537
# Epoch = 178 RMSE Training Loss = 0.53535
# Epoch = 179 RMSE Training Loss = 0.53533
# Epoch = 180 RMSE Training Loss = 0.53530
#
#
#
# Training Eneded for 180 epochs
# MAPE: 0.04651
# Epoch = 181 RMSE Training Loss = 0.53529
# Epoch = 182 RMSE Training Loss = 0.53527
# Epoch = 183 RMSE Training Loss = 0.53525
# Epoch = 184 RMSE Training Loss = 0.53523
# Epoch = 185 RMSE Training Loss = 0.53520
# Epoch = 186 RMSE Training Loss = 0.53519
# Epoch = 187 RMSE Training Loss = 0.53518
# Epoch = 188 RMSE Training Loss = 0.53516
# Epoch = 189 RMSE Training Loss = 0.53515
# Epoch = 190 RMSE Training Loss = 0.53511
#
#
#
# Training Eneded for 190 epochs
# MAPE: 0.04650
# Epoch = 191 RMSE Training Loss = 0.53511
# Epoch = 192 RMSE Training Loss = 0.53509
# Epoch = 193 RMSE Training Loss = 0.53507
# Epoch = 194 RMSE Training Loss = 0.53505
# Epoch = 195 RMSE Training Loss = 0.53504
# Epoch = 196 RMSE Training Loss = 0.53501
# Epoch = 197 RMSE Training Loss = 0.53500
# Epoch = 198 RMSE Training Loss = 0.53500
# Epoch = 199 RMSE Training Loss = 0.53496
# Epoch = 200 RMSE Training Loss = 0.53495
#
#
#
# Training Eneded for 200 epochs
# MAPE: 0.04650

# %%
result_list = sorted(result_dict.items(), key=lambda item:item[1])

# %%
for item in result_list:
  str = item[0]+' '+item[1]+'\n'
  print(str)
# Out:
# 190E 0.04650
#
# 200E 0.04650
#
# 180E 0.04651
#
# 170E 0.04652
#
# 160E 0.04653
#
# 150E 0.04654
#
# 140E 0.04655
#
# 130E 0.04657
#
# 120E 0.04659
#
# 110E 0.04664
#
# 100E 0.04671
#
# 90E 0.04684
#
# 80E 0.04714
#
# 70E 0.04787
#
# 60E 0.04952
#
# 50E 0.05302
#
# 40E 0.05691
#
# 30E 0.06279
#
# 20E 0.07019
#
# 10E 0.07653

# %%
# import torch
# t1 = torch.tensor([1,2,3], dtype=torch.float)
# t2 = torch.tensor([2,3,4], dtype=torch.float)

# t3 = torch.tensor([4,5,6], dtype=torch.float)
# t4 = torch.tensor([5,6,7], dtype=torch.float)

# # RMSE = 0

# # mse = nn.MSELoss()

# # RMSE += mse(t1,t2)
# # print(RMSE)
# # RMSE += mse(t3,t4)
# # torch.sqrt(RMSE/2)

# %%
# t1 = torch.tensor([1,2,3,4,5,6], dtype=torch.float)
# t2 = torch.tensor([2,3,4,5,6,7], dtype=torch.float)
# RMSE = 0

# mse = nn.MSELoss()

# RMSE = torch.sqrt(mse(t1,t2))
# print(RMSE)

# %%
# mse = 0
# mse += torch.sum((t1-t2)**2)
# mse += torch.sum((t3-t4)**2)
# torch.sqrt(mse/6)
